# %%
import seaborn as sns
df=sns. load_dataset ('tips' )
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
df.dtypes
# Out:
# total_bill     float64
# tip            float64
# sex           category
# smoker        category
# day           category
# time          category
# size             int64
# dtype: object

# %%
#corr()
#feature selection
df.corr(numeric_only=True)
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
#total_bill affects tip most
sns.heatmap(df.corr(numeric_only=True))
#chisquare test
# Out:
# <Axes: >

# %%
#join plot
#scatter plot=====regline()
#jointplot used for numerical columns
sns. jointplot (x='tip' , y='total_bill' , data=df)

# %%
sns.jointplot (x='tip',y='size',data=df)

sns. jointplot (x='size',y='total_bill', data=df)

# %%
#pair plot

#tip
#tipsize
#total bill
#total bill size
sns.pairplot (df,kind='reg' )

# %%
sns.pairplot (df,kind='hex' )

# %%
df ['smoker' ] . value_counts ( )
# Out:
# smoker
# No     151
# Yes     93
# Name: count, dtype: int64

# %%
df ['day' ]. value_counts ()
# Out:
# day
# Sat     87
# Sun     76
# Thur    62
# Fri     19
# Name: count, dtype: int64

# %%
df ['time' ]. value_counts ()
# Out:
# time
# Dinner    176
# Lunch      68
# Name: count, dtype: int64

# %%
#object
sns.pairplot (df, hue='day')

# %%
#object
sns.pairplot (df, hue='time')

# %%
#count plot
#bar
sns. countplot (x='day',data=df,color="r", hue="smoker")
# Out:
# C:\Users\anjan\AppData\Local\Temp\ipykernel_7756\3775010477.py:3: FutureWarning:
#
# Setting a gradient palette using color= is deprecated and will be removed in v0.14.0. Set `palette='dark:r'` for the same effect.
#
#   sns. countplot (x='day',data=df,color="r", hue="smoker")
# <Axes: xlabel='day', ylabel='count'>

# %%
#barplot

sns.barplot (x='total_bill' ,y='day' , data=df)
# Out:
# <Axes: xlabel='total_bill', ylabel='day'>

# %%
#Boxplot()
#
sns. boxplot (x='total_bill' , data=df)

#
# Out:
# <Axes: xlabel='total_bill'>

# %%
#Boxplot()
#
sns. boxplot (y='total_bill' , data=df)

#
# Out:
# <Axes: ylabel='total_bill'>

# %%
df["total_bill"].unique()
# Out:
# array([16.99, 10.34, 21.01, 23.68, 24.59, 25.29,  8.77, 26.88, 15.04,
#        14.78, 10.27, 35.26, 15.42, 18.43, 14.83, 21.58, 10.33, 16.29,
#        16.97, 20.65, 17.92, 20.29, 15.77, 39.42, 19.82, 17.81, 13.37,
#        12.69, 21.7 , 19.65,  9.55, 18.35, 15.06, 20.69, 17.78, 24.06,
#        16.31, 16.93, 18.69, 31.27, 16.04, 17.46, 13.94,  9.68, 30.4 ,
#        18.29, 22.23, 32.4 , 28.55, 18.04, 12.54, 10.29, 34.81,  9.94,
#        25.56, 19.49, 38.01, 26.41, 11.24, 48.27, 13.81, 11.02, 17.59,
#        20.08, 16.45,  3.07, 20.23, 15.01, 12.02, 17.07, 26.86, 25.28,
#        14.73, 10.51, 27.2 , 22.76, 17.29, 19.44, 16.66, 10.07, 32.68,
#        15.98, 34.83, 13.03, 18.28, 24.71, 21.16, 28.97, 22.49,  5.75,
#        16.32, 22.75, 40.17, 27.28, 12.03, 12.46, 11.35, 15.38, 44.3 ,
#        22.42, 20.92, 15.36, 20.49, 25.21, 18.24, 14.31, 14.  ,  7.25,
#        38.07, 23.95, 25.71, 17.31, 29.93, 10.65, 12.43, 24.08, 11.69,
# ...

# %%
#Boxplot()
#
sns. boxplot (y='tip' , data=df)

#
# Out:
# <Axes: ylabel='tip'>

# %%
#min,25 percentile(Q1),50 Percentile(Q2),75 Percentile (Q3),max

# %%
#3,7,1,1,8,4,6,9

#1,1,3,4   6,7,8,9

#Median =4+6/2=5 Q2

#Medain =1+3/2=2 Q1

#Median -7+8/2-7.5 Q3
#IQR(Inter Quartile Range) =(Q3-Q1) =7.5-2 =5.5//
#Top_Outliers = (Q3+1.5IQR) =[7.5+1.5*5.5]=15.75 //

#Bottom Outliers = (Q1-1.5IQR) =[2-1.5*5.5]=- 6.25 //

# %%
import numpy as np
Q1 = np.percentile(df['total_bill' ], 25, method='midpoint')
Q3 = np.percentile(df['total_bill' ], 75, method='midpoint' )
IQR = Q3 - Q1 #
print(IQR)



#q1
#q3

#
# Out:
# 10.849999999999998

# %%
upper = Q3+1.5*IQR
upper_array = np.array(df ['total_bill' ] >= upper) #[1,2,3,4]
print("Upper Bound:", upper)
print(upper_array.sum () )

# Below Lower bound
lower = Q1-1.5*IQR
lower_array = np.array(df ['total_bill' ] <= lower)
print ("Lower Bound:", lower)
print(lower_array. sum( ) )
# Out:
# Upper Bound: 40.449999999999996
# 9
# Lower Bound: -2.9499999999999993
# 0

# %%
upper = Q3+1.5*IQR
upper_array = np.array(df [ 'total_bill' ] >= upper) #[1,2,3,4]
#

print("Upper Bound:", upper)
print (upper_array)
print(upper_array. sum ( ) )

# # Below Lower bound
# lower = Q1-1.5*IQR
# lower array = np.array(df['total_bill' ] <= lower)
# print("Lower Bound:", lower)
# print (lower array. sum() )
# Out:
# Upper Bound: 40.449999999999996
# [False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False  True
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False  True False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False  True False
# ...

# %%
import matplotlib.pyplot as plt
def removal_box_plot(df, column, threshold): #arguments
    sns.boxplot (df [column]) #df ['total bill] #sns. boxplot(df ['toatl_bill])
    plt.title(f'Original Box Plot of {column}' ) #40
    plt.show()

    removed_outliers = df [df ['total_bill'] <= threshold]

    sns.boxplot (removed_outliers ['total_bill'] )
    plt. title(f'Box Plot without Outliers of {column}')
    plt.show ( )
    return removed_outliers

#

threshold_value = 40

no_outliers = removal_box_plot(df, 'total_bill', threshold_value) #()
